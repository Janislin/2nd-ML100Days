# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 數據集：https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews#Womens%20Clothing%20E-Commerce%20Reviews.csv
#
# 1. 你選的這組資料為何重要
#
# Ａ： 透過變量的改變，可觀察出女性消費者對於網購商品的喜好程度以及評價，這些所蒐集到的數據能讓電商公司瞭解到顧客是如何看待他們的產品或服務，並且去改進。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Ａ： Nick Brooks，以問卷的方式讓消費者進行評論。
#
# 3. 蒐集而來的資料型態為何
#
# Ａ： Integer、String。
#
# 4. 這組資料想解決的問題如何評估
#
# Ａ： 透過評論以及等級評分來觀察消費者對於各種分類商品的喜好程度，再進一步去思考下一季所要上架的商品。
#
#
#
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# Ａ：如果在車上裝卡拉ＯＫ會吸引顧客並提升業績嗎？
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# Ａ： 透過問卷以及Facebook社團散布問卷連結，但是有些人可能會害羞不敢唱歌，或是當天生病感冒、急著去某個地方所以沒心情唱歌，這些因素都會影響問卷的結果。
#
# 3. 蒐集而來的資料型態為何
#
# Ａ：String、Integer。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# Ａ： 從問卷的評論及數據蒐集期間的營業額去觀察在車上裝卡拉ＯＫ相較於一般情況的業績是否有提升。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, yp):
    mse = MSE = sum(abs(y - yp)**2) / len(y)
    return mse

# %%
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 184.897
